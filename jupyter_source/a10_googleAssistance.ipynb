# %%
from popAssist import *

# %%
import popAssist
print(popAssist.__file__)
# Out:
# /usr/local/lib/python3.6/dist-packages/popAssist.py

# %%
from popAssist import *

stream = create_conversation_stream()
ga = GAssistant(stream)

print("Taking about ...")
ga.assist()

print("Bye...")
stream.close()
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# <ipython-input-4-33d4a0e87664> in <module>
#       2
#       3 stream = create_conversation_stream()
# ----> 4 ga = GAssistant(stream)
#       5
#       6 print("Taking about ...")
#
# /usr/local/lib/python3.6/dist-packages/popAssist.py in __init__(self, conversation_stream, local_device_handler, google_device_handler, lang, display)
#      69             credentials = google.oauth2.credentials.Credentials(token=None, **json.load(f))
#      70             http_request = google.auth.transport.requests.Request()
# ---> 71             credentials.refresh(http_request)
#      72
#      73         api_endpoint = ASSISTANT_API_ENDPOINT
#
# /usr/local/lib/python3.6/dist-packages/google/oauth2/credentials.py in refresh(self, request)
#     208             self._client_id,
#     209             self._client_secret,
# ...
