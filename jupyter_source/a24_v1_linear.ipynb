# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

W = tf.Variable(1.)
B = tf.Variable(0.)
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
H = W * X + B
Loss = tf.reduce_mean(tf.reduce_mean(Y-H))
print(type(H))
# Out:
# <class 'tensorflow.python.framework.ops.Tensor'>

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate= 0.001)
train_op = optimizer.minimize(Loss)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
import numpy as np
X_data = np.array([0,1,2,3,4]).reshape(1, -1)
Y_data = np.array([0,2,4,6,8]).reshape(1, -1)

for i in range(1000):
    sess.run(train_op, feed_dict={X: X_data, Y: Y_data})
    loss = sess.run(Loss, feed_dict={X: X_data, Y: Y_data})
#     print(loss)

# %%
n = np.array([7, -10, 358]).reshape(1, -1)
re = sess.run(H, feed_dict={X: n})
print(re)
# Out:
# [[  38.499985  -49.899906 1863.6976  ]]
