# %%
from pop import AI
LR = AI.Logistic_Regression()

# %%
LR.X_data = [[173],[171],[162],[187],[157],[169],[177]]  # 입력값
LR.Y_data = [[0],[1],[1],[0],[1],[0],[0]]  # 레이블

# %%
LR.train()
# Out:
# 10 step loss: 4.761822700500488
# 20 step loss: 15.99750804901123
# 30 step loss: 8.025644302368164
# 40 step loss: 1.2239316701889038
# 50 step loss: 0.8211236596107483
# 60 step loss: 1.2502774000167847
# 70 step loss: 0.9096836447715759
# 80 step loss: 0.7320728898048401
# 90 step loss: 0.6966717839241028
# 100 step loss: 0.6933146715164185
# Training is done.
# Time spent: 22.6 s
# Training speed: 4.4 step/s

# %%
LR.run()
# Out:
# run with :  [[173]
#  [171]
#  [162]
#  [187]
#  [157]
#  [169]
#  [177]]
# array([[0.4354906 ],
#        [0.43458012],
#        [0.4304886 ],
#        [0.4418757 ],
#        [0.42821953],
#        [0.43367007],
#        [0.4373128 ]], dtype=float32)

# %%
LR.train(times=10000, print_every=1000)
# Out:
# 1100 step loss: 0.5384578704833984
# 2100 step loss: 0.4388153851032257
# 3100 step loss: 0.39315858483314514
# 4100 step loss: 0.36837413907051086
# 5100 step loss: 0.3534354567527771
# 6100 step loss: 0.3437914252281189
# 7100 step loss: 0.337250292301178
# 8100 step loss: 0.33265724778175354
# 9100 step loss: 0.3293408751487732
# 10100 step loss: 0.32689136266708374
# Training is done.
# Time spent: 68.5 s
# Training speed: 145.9 step/s

# %%
LR.run()
# Out:
# run with :  [[173]
#  [171]
#  [162]
#  [187]
#  [157]
#  [169]
#  [177]]
# array([[0.2934551 ],
#        [0.43822637],
#        [0.9300848 ],
#        [0.0050126 ],
#        [0.9846889 ],
#        [0.5943407 ],
#        [0.10533845]], dtype=float32)

# %%
re = LR.run()
# Out:
# run with :  [[173]
#  [171]
#  [162]
#  [187]
#  [157]
#  [169]
#  [177]]

# %%
print(re[re > 0.5])
print(re > 0.5)
# Out:
# [0.9300848 0.9846889 0.5943407]
# [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]]

# %%
LR = AI.Logistic_Regression(restore=True, ckpt_name="model_1")
# Out:
# [Error] Can't find a model in 'model_1'.
# Create a new model.

# %%
LR.save()
