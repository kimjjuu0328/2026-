# %%
from pop import Pilot

LED=Pilot.PWM(1,0x5c)
LED.setFreq(50)

# 빨간색 앞 두개 뒤 두개
LED.setDuty(0,99) 
LED.setDuty(1,99)
LED.setDuty(2,99)
LED.setDuty(3,99)

LED.setDuty(0,0)
LED.setDuty(1,0)
LED.setDuty(2,0)
LED.setDuty(3,0)

# %%
# 초록색 앞 두개 뒤 두개
LED.setDuty(4,99)
LED.setDuty(5,99)
LED.setDuty(6,99)
LED.setDuty(7,99)

# %%
LED.setDuty(0,0)
LED.setDuty(1,0)
LED.setDuty(2,0)
LED.setDuty(3,0)
LED.setDuty(4,0)
LED.setDuty(5,0)
LED.setDuty(6,0)
LED.setDuty(7,0)

# %%
LED=Pilot.PWM(1,0x5c)
LED.setFreq(50)

dtime = time.time()
lasttime=0
sw=0
while time.time()-dtime<30:
    if time.time()-lasttime>1:
        if sw==0:
            LED.setDuty(0,99)
            LED.setDuty(1,99)
            LED.setDuty(2,99)
            LED.setDuty(3,99)
        elif sw==2:
            LED.setDuty(4,99)
            LED.setDuty(5,99)
            LED.setDuty(6,99)
            LED.setDuty(7,99)
        else:
            LED.setDuty(0,0)
            LED.setDuty(1,0)
            LED.setDuty(2,0)
            LED.setDuty(3,0)
            LED.setDuty(4,0)
            LED.setDuty(5,0)
            LED.setDuty(6,0)
            LED.setDuty(7,0)
        sw+=1
        sw%=4
        lasttime=time.time()

# %%
from pop import Pilot
car = Pilot.AutoCar()
car.stop()
car.turnCenter()
car.cam2Front()

# %%
car.joystick()
# Out:
# <style>.joystick_focused{ cursor:grabbing !important;}    .joystick_background{user-select: none;        background: #fff3f3;        border: 1px solid #ffa29e;        border-radius: 50%;        height: 12em;        width: 12em;    margin:2.5em;}    .joystick_stick{cursor:grab; user-select: none;        background: #F74138;        border-radius: 50%;        box-shadow: 0.375em 0.375em 0 0 rgba(15, 28, 63, 0.125);        height: 5em;        width: 5em;        transform: translate(50%,50%);    }</style><div><div id="joystick_background_530DE825D73C04" class="joystick_background">    <div id="joystick_stick_530DE825D73C04" class="joystick_stick" style="position:absolute" onmousedown="start_joystick_530DE825D73C04(this); joystick_focus_530DE825D73C04(this);" ondrag="joystick_530DE825D73C04(e)" onmouseup="reset_joystick_530DE825D73C04(this); joystick_disfocus_530DE825D73C04(this);"></div></div></div><script> X=0; Y=0; function joystick_focus_530DE825D73C04(e){ e.classList.add("joystick_foc
# ...

# %%
from pop import Pilot
car = Pilot.AutoCar()
LED=Pilot.PWM(1,0x5c)
LED.setDuty(7,99)

# %%
LED.setDuty(7,0)

# %%
# LED.setDuty()
LED.setDuty(0,99)    # 전방 오른쪽 빨간색
LED.setDuty(1,99)    # 전방 왼쪽 빨간색
LED.setDuty(2,99)    # 후방 오른쪽 빨간색
LED.setDuty(3,99)    # 후방 왼쪽 빨간색
# LED.setDuty(5,99)
# LED.setDuty(6,99)

# %%
LED.setDuty(4,99)
LED.setDuty(5,99)
LED.setDuty(6,99)
LED.setDuty(7,99)

# %%
LED.setDuty(0,0)
LED.setDuty(1,0)
LED.setDuty(2,0)
LED.setDuty(3,0)
LED.setDuty(4,0)
LED.setDuty(5,0)
LED.setDuty(6,0)
