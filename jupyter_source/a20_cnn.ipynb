# %%
from pop import AI

cnn = AI.CNN(output_size=10)

cnn.load_MNIST()
cnn.show_img(cnn.X_data[501])   # 28 * 28 , 60000 개  , (10,) , 60000 개

# %%
cnn.show_img(cnn.X_data[500])

# %%
cnn.show_img(cnn.X_data[301])

# %%
print(cnn.X_data[301].shape)

# %%
print(len(cnn.X_data))

# %%
print(cnn.Y_data[301], len(cnn.Y_data) )

# %%
cnn.model.summary()

# %%
cnn.train()

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices("GPU")

# %%
print(gpus)

# %%
X = [cnn.X_data[10]]
cnn.run(X)
