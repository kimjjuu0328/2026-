# %%
from tensorflow import keras
import tensorflow as tf

model = keras.models.Sequential()

model.add(keras.layers.Input(shape=(3,)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(2, activation='sigmoid'))

model.compile(loss="binary_crossentropy", optimizer="Adam")

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 100)               400
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
X=[[1,-2,3],[2,-3,4],[3,5,4],[4,-5,6],[7,-5,3], [1,6,8], [3,8,1]]
Y=[[0, 1],[0, 1],[1, 0],[0, 1],[1, 1],[0, 1],[1, 1]]

model.fit(X, Y, epochs=20)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6394
# Epoch 2/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5780
# Epoch 3/20
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5319
# Epoch 4/20
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4932
# Epoch 5/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4583
# Epoch 6/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4264
# Epoch 7/20
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3971
# Epoch 8/20
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3700
# Epoch 9/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3453
# Epoch 10/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3221
# Epoch 11/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2994
# Epoch 12/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2775
# Epoch 13/20
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2560
# Epoch 14/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2344
# Epoch 15/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2139
# Epoch 16/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1937
# Epoch 17/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1743
# Epoch 18/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1558
# Epoch 19/20
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1386
# Epoch 20/20
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1224

# %%
value = model.predict([[10,-5,3], [-1,6,-8], [3,5,8]])
print(value)
# Out:
# [[0.9693616  0.99903905]
#  [0.9805115  0.94561046]
#  [0.12496272 0.8422342 ]]
