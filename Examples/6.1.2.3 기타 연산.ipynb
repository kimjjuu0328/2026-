# %%
import numpy as np

x =  np.arange(4).reshape(2,2) #Numpy의 ndarray을 0 부터 3까지로 채워 생성하고 2,2 형태로 변형
print(x)

s1 =  np.abs(x) #ndarray x 원소들의 절대값을 반환
print(s1)
s2 =  np.square(x) #ndarray x 원소들의 제곱을 반환
print(s2)
s3 =  np.sqrt(x) #ndarray x 원소들의 제곱근을 반환
print(s3)
s4 =  np.log(x) #ndarray x 원소들의 로그값을 반환
print(s4)
