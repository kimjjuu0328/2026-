# %%
import pyaudio
import numpy as np

volume = 0.5
fs = 48000 # 샘플링 주파수 (연속적인 신호에서 얻어진 단위시간(초) 당 샘플링 횟수
duration = 1.0
f = 440.0 # 4옥타브 "라"

data = (np.sin(2 * np.pi * np.arange(fs * duration) * f/fs)).astype(np. float32)

p = pyaudio.PyAudio()
stream = p.open(format=pyaudio.paFloat32, channels=1, rate=fs, output=True)
stream.write(volume * data)

stream.stop_stream()
stream.close() 
p.terminate()
