# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.random.random(1000).reshape(2,500) #1000개의 랜덤 값을 가진 1차원 ndarray 생성하고 2,500 형태로 변환
plt.scatter(data[0], data[1]) #산점도 그래프로 출력
plt.show()
