# %%
import pandas as pd

value = [32, 68, 220, 72]
index = ["온도", "습도", "강수량", "불쾌지수"]
sr = pd.Series(value, index=index)

print(type(sr)) #시리즈의 타입을 반환
print(sr) #시리즈를 반환
print(sr["온도"]) #시리즈에서 "온도" 값을 반환

# %%
print(sr.index) #시리즈의 인덱스를 반환
print(sr.values) #시리즈의 값을 반환
