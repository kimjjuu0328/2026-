# %%
import numpy as np

x =  np.arange(4).reshape(2,2) #Numpy의 ndarray을 0 부터 3까지로 채워 생성하고 2,2 형태로 변형
print(x)
y =  np.arange(3,-1,-1).reshape(2,2) #Numpy의 ndarray을 3 부터 0까지로 채워 생성하고 2,2 형태로 변형
print(y)

s1 = x + y #ndarray x와 y를 덧셈하여 반환
print(s1)
s2 = x - y #ndarray x에 y를 뺄셈하여 반환
print(s2)
s3 = x * y #ndarray x와 y를 곱셈하여 반환
print(s3)
s4 = x / y #ndarray x와 y를 나눗셈하여 반환
print(s4)

# %%
import numpy as np

x =  np.arange(4).reshape(2,2) #Numpy의 ndarray을 0 부터 3까지로 채워 생성하고 2,2 형태로 변형
print(x)
y =  np.arange(3,-1,-1).reshape(2,2) #Numpy의 ndarray을 3 부터 0까지로 채워 생성하고 2,2 형태로 변형
print(y)

s1 =  np.add(x,y) #ndarray x와 y를 덧셈하여 반환
print(s1)
s2 = np.subtract(x,y) #ndarray x에 y를 뺄셈하여 반환
print(s2)
s3 = np.multiply(x,y) #ndarray x와 y를 곱셈하여 반환
print(s3)
s4 = np.divide(x,y) #ndarray x와 y를 나눗셈하여 반환
print(s4)
