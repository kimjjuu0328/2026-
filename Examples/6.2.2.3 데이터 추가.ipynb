# %%
import pandas as pd

value = [[32, 68, 220, 72],
	[28, 30, 0, 12],
	[38, 81, 0, 91]]
columns = ["온도", "습도", "강수량", "불쾌지수"]
index = ["초여름", "늦봄", "한여름"]
df = pd.DataFrame(value, index=index, columns=columns)

value2 = [[37, 90, 120, 94]]
index2 = ["한여름"]
df2 = pd.DataFrame(value2, index=index2, columns=columns)

print(df.append(df2)) #새로운 데이터 프레임을 추가하여 반환

# %%
import pandas as pd

value = [[32, 68, 220, 72],
	[28, 30, 0, 12],
	[38, 81, 0, 91]]
columns = ["온도", "습도", "강수량", "불쾌지수"]
index = ["초여름", "늦봄", "한여름"]
df = pd.DataFrame(value, index=index, columns=columns)

df.insert(0, "자외선", [6, 3, 7]) #데이터 프레임에 열 중 0번째 열에 새로운 열을 추가하고 값을 지정
print(df)

# %%
import pandas as pd

value = [[32, 68, 220, 72],
	[28, 30, 0, 12],
	[38, 81, 0, 91]]
columns = ["온도", "습도", "강수량", "불쾌지수"]
index = ["초여름", "늦봄", "한여름"]
df = pd.DataFrame(value, index=index, columns=columns)

df.insert(0, "자외선", 0) #데이터 프레임에 열 중 0번째 열에 새로운 열을 추가하고 값을 0으로 초기화
print(df)
