# %%
from pop import Tone

shoolBall1 = ((4, "SOL", 1/4), (4, "SOL", 1/4), (4, "RA", 1/4), (4, "RA", 1/4),        (4, "SOL", 1/4), (4, "SOL", 1/4), (4, "MI", 1/2), (4, "SOL", 1/4),        (4, "SOL", 1/4), (4, "MI", 1/4), (4, "MI", 1/4), (4, "RE", 1/2 + 1/4))

shoolBall2 = (*shoolBall1[:7], (4, "SOL", 1/4), (4, "MI", 1/2), (4, "SOL", 1/4),       (4, "MI", 1/4), (4, "RE", 1/4), (4, "MI", 1/4), (4, "DO", 1/2 + 1/4))

with Tone() as tone:
    tone.setTempo(200)

    for n in shoolBall1:
        tone.play(*n)
    tone.rest(1/4)

    for n in shoolBall2:
        tone.play(*n)
    tone.rest(1/4)
