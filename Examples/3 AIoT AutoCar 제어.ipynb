# %%
import time
from pop import Pilot

Car = Pilot.AutoCar()

# %%
Car.steering = -1

time.sleep(1)

Car.steering = 1

# %%
Car.forward()

time.sleep(1)

Car.backward()

time.sleep(1)

Car.stop()

# %%
Car.setSpeed(50)
Car.forward()

time.sleep(1)

Car.backward(99)

time.sleep(1)

Car.stop()

# %%
Car.joystick()

# %%
Car.camPan(0)

time.sleep(1)

Car.camPan(180)

time.sleep(1)

Car.camTilt(180)

time.sleep(1)

Car.camTilt(0)

# %%
value = Car.getGyro()
print(value)

time.sleep(1)

value = Car.getGyro("z")
print(value)

# %%
value = Car.getAccel()
print(value)

time.sleep(1)

value = Car.getAccel("z")
print(value)
