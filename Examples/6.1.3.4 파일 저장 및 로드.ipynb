# %%
import numpy as np

x =  np.random.random(20) #랜덤 값 20개를 생성
print(x)

np.save("randoms", x)

y=np.load("randoms.npy")
print(y)

# %%
import numpy as np

x =  np.random.random(20) #랜덤 값 20개를 생성
print(x)
y =  np.random.random(2) #랜덤 값 20개를 생성
print(y) 

np.savez("randoms", arr1=x, arr2=y)

z=np.load("randoms.npz")
print(z["arr1"])
print(z["arr2"])
z.close()

# %%
import numpy as np

x =  np.arange(20) #순서 값 20개를 생성
print(x) 

np.savetxt("texts.txt", x)

y=np.loadtxt("texts.txt")
print(y)
