# %%
import pandas as pd

value = [[7, 5],
    [5, 1],
    [3, -1]]
df = pd.DataFrame(value)

print(df.sum(0))
print(df.mean(0))
print(df.std(0))
print(df.var(0))

# %%
print(df.sum(1))
print(df.mean(1))
print(df.std(1))
print(df.var(1))
